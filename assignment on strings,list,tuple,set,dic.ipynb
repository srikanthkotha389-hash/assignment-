# %%
a='srikanth'

# %%
len(a)
# Out:
# 8

# %%
a="aimnext"

# %%
a[::-1]
# Out:
# 'txenmia'

# %%
A='srikanth'
b=A.replace('a','@')
print(b)
# Out:
# srik@nth

# %%
a='srikanth reddy'

# %%
a.count('e')
# Out:
# 1

# %%
a='srikanth'

# %%
a[0],a[-1]
# Out:
# ('s', 'h')

# %%
a='aim'
b='next'
c=a+b
print(c)
# Out:
# aimnext

# %%
a='data science'
'python'in a
# Out:
# False

# %%
a='aim next in hyderabad'
a.replace(' ','')
# Out:
# 'aimnextinhyderabad'

# %%
a
# Out:
# 'aim next in hyderabad'

# %%
a[0:4]
# Out:
# 'aim '

# %%
a=[1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a[2]
# Out:
# 3

# %%
a[1]='hello'
print(a)
a
# Out:
# [1, 'hello', 3, 4, 5, 'data science', 'data science']
# [1, 'hello', 3, 4, 5, 'data science', 'data science']

# %%
l=[1,2,3,4,5]

# %%
l.append('data science')
print(l)
# Out:
# [1, 2, 3, 4, 5, 'data science']

# %%
l.pop()
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
10 in l
# Out:
# False

# %%
l=[1,2,3,4,5]
m=[2,3,4,56,78]
print(l+m)
# Out:
# [1, 2, 3, 4, 5, 2, 3, 4, 56, 78]

# %%
l.reverse()

# %%
print(l)
# Out:
# [5, 4, 3, 2, 1]

# %%
l.sort()
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
t=('red','white','green')
print(t)
# Out:
# ('red', 'white', 'green')

# %%
t[1]
# Out:
# 'white'

# %%
t[1]='aimnext'
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 t[1]='aimnext'
#       2 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(1,2,4,'aimnext')

# %%
t=[t]
print(t)
# Out:
# [(1, 2, 4, 'aimnext')]

# %%
type(t)
# Out:
# list

# %%
t=('red','white','green')
'blue'in t
# Out:
# False

# %%
t=('red','white','green')
s=(1,2,3,4,'srikanth')
print(t+s)
# Out:
# ('red', 'white', 'green', 1, 2, 3, 4, 'srikanth')

# %%
t[::-1]
# Out:
# ('green', 'white', 'red')

# %%
t=(1)

# %%
type(t)
# Out:
# int

# %%
s='hello world'

# %%
s[6:11]
# Out:
# 'world'

# %%
a='hello world'
if a.startswith('hello'):
 print("yes")
else:
    print("no")
# Out:
# yes

# %%
a='aim next hyderabad'

# %%
a[2]
# Out:
# 'm'

# %%
a='aim next hyderabad' 
for vowel in "aeiouAEIOU":
        a = a.replace(vowel, "*")

print("String after replacing vowels:", a)
# Out:
# String after replacing vowels: **m n*xt hyd*r*b*d

# %%
a='aim next'
b='hyderabad'
if a==b:
    print('same')
else:
        print('not same')
# Out:
# not same

# %%
a='aim next hyderabad'
a[0],a[-1]
# Out:
# ('a', 'd')

# %%
a='12345'
a=[1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
l=['hyderabad','delhi','chennai','kerala','mumbai']
l[0:3]
# Out:
# ['hyderabad', 'delhi', 'chennai']

# %%
l=['hyderabad','delhi','chennai','kerala','mumbai']
l.pop(2)
# Out:
# 'chennai'

# %%
a=1,2,3,4,5
a=[a]

# %%
a
# Out:
# [(1, 2, 3, 4, 5)]

# %%
type(a)
# Out:
# list

# %%
l=["banana", "orange", "apple", "grape"]
l.index('apple')
# Out:
# 2

# %%
l=[1,2,3,4,5,6,7]
print('even numbers')
for num in l:
 if num%2==0:
    print (num)
# Out:
# even numbers
# 2
# 4
# 6

# %%
l=[1,2,3,4,5,6,7]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l=[1,2,3,4,5,6,7]
l[0]=7
l[1]=6
l[2]=5
l[3]=4
l[4]=3
l[5]=2
l[6]=1

# %%
l
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
l=[1,2,2,3,4,55,66,77,77,88,99]
print(l)
# Out:
# [1, 2, 2, 3, 4, 55, 66, 77, 77, 88, 99]

# %%
l=list(set(l))

# %%
l
# Out:
# [1, 2, 3, 4, 66, 99, 77, 55, 88]

# %%
l=["banana", "orange", "apple", "grape"]
print(l)
# Out:
# ['banana', 'orange', 'apple', 'grape']

# %%
l[0]='grape'
l[-1]='banana'
print(l)
# Out:
# ['grape', 'orange', 'apple', 'banana']

# %%
l=[1,2,3,4,5,'harsha',45.67,True]
print(type(0))
print(type('harsh'))
print(type(45.67))
print(type(True))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
t=(1,2,3,4,5,6)
print(t[5])
# Out:
# 6

# %%
t=(1,2,3,4,5)
print(t[0:3])
# Out:
# (1, 2, 3)

# %%
t=(1,2,3,4,5)
t=[(1,2,3,4,5)]
t.append(6)
print(t)
# Out:
# [(1, 2, 3, 4, 5), 6]

# %%
type(t)
# Out:
# list

# %%
t=(1,2,3,4,5)
t.pop(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 t=(1,2,3,4,5)
# ----> 2 t.pop(2)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t=(1,2,3,4,5)
print(t[2])
# Out:
# 3

# %%
t=(1, 2, 3)
h=(3, 2, 1)
if t==h:
    print('same')
else:
    print('not same')
# Out:
# not same

# %%
t=(1,2,3,(2,3,4),6,7)
t[3][1]
# Out:
# 3

# %%
t=(1, 2, 3)
h=(3, 2, 1)
s=(4,5,6)
a=t+h+s
print(a)
# Out:
# (1, 2, 3, 3, 2, 1, 4, 5, 6)

# %%
t=(1, 3, 5, 7, 9)
t.index(5)
# Out:
# 2

# %%
t=(1, 2, 3)
print(t[0])
print(t[1])
print(t[2])
# Out:
# 1
# 2
# 3

# %%
d={'name': "Alice", 'age': 25, 'city': "New York"}
print(d)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
type(d)
# Out:
# dict

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
person["city"]
# Out:
# 'New York'

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
person["age"]=26
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'New York'}

# %%
person["gmail"]="alice@example.com" 
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'New York', 'gmail': 'alice@example.com'}

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
del person["city"]
print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
person={'name': 'Alice', 'age': 26, 'city': 'New York', 'gmail': 'alice@example.com'}

# %%
'gmail' in person
# Out:
# True

# %%
score= { "Alice": {"math": 90, "science": 85},
"Bob": {"math": 75, "science": 95}}
score["Bob"]["science"]
# Out:
# 95

# %%
fruits={"apple", "banana", "cherry"}

# %%
fruits.add("orange")
print(fruits)
# Out:
# {'apple', 'orange', 'banana', 'cherry'}

# %%
fruits={"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'apple', 'cherry'}

# %%
fruits.remove("mango")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [138], in <cell line: 1>()
# ----> 1 fruits.remove("mango")
#
# KeyError: 'mango'

# %%
fruits={"apple", "banana", "cherry"}
"apple" in fruits
# Out:
# True

# %%
l=[1, 2, 2, 3, 4, 4, 5]
l=list(set(l))
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
a="hello world and hello python"
a=str(set(a))
print(a)
# Out:
# {'l', 'w', 'h', 'o', 'n', 'a', 't', ' ', 'p', 'd', 'r', 'y', 'e'}
